# %%
from pandas import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
options.display.max_columns = 999
options.display.max_rows = 999

# %matplotlib inline

# %%
ls
# Out:
# analysis.ipynb             sample_submission.csv.zip  test.csv.zip               train.csv.zip
# sample_submission.csv      test.csv                   train.csv

# %%
df_sub = read_csv('sample_submission.csv')

# %%
df_train = read_csv('train.csv')
df_train.head()
# Out:
#    Id  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1        NaN        NaN        NaN        NaN          8        NaN
# 1   2        NaN        NaN        NaN        NaN          3   0.388896
# 2   3        NaN  -0.696727   0.739591  -0.167928          9   0.471947
# 3   4        NaN  -0.694350   1.568248   0.479073          5   0.120653
# 4   5          6  -1.736489   2.765531   1.245280          7   4.866985
#
#    Feature_7  Feature_8  Feature_9  Feature_10  Feature_11  Feature_12  \
# 0      75751     0.2254         11         NaN         NaN        0.49
# 1      17369     0.0166         13         NaN   -0.409923        0.71
# 2       8277     0.3650          9           5   -0.473024        0.03
# 3      22508     0.2654         13           5   -2.138383        0.00
# 4      22423     0.2138         13           4   -4.795565        0.97
#
#    Feature_13  Feature_14  Feature_15  Feature_16  Feature_17  Feature_18  \
# ...

# %%
df_train.describe().T
# Out:
#                  count          mean            std             min  \
# Id               40000  2.000050e+04   11547.149720        1.000000
# Feature_1         6687  3.590250e+00       2.798532        1.000000
# Feature_2        30854 -1.175579e-01       1.236250       -3.440521
# Feature_3        38763  5.583925e-01       0.902233       -4.643526
# Feature_4        32279  4.055716e-01       0.799082       -5.440596
# Feature_5        40000  5.482775e+00       2.942324        1.000000
# Feature_6        38067  4.309716e-01       1.498274       -0.936644
# Feature_7        40000  4.924497e+04   28242.409717      338.000000
# Feature_8        39531  1.969580e-01       0.138485        0.009800
# Feature_9        38125  1.068029e+01       2.850634        0.000000
# Feature_10       20529  4.744703e+00       0.865096        1.000000
# Feature_11       39013 -5.722444e-01       1.246347       -7.359120
# Feature_12       38904  4.985084e-01       0.351855        0.000000
# ...
